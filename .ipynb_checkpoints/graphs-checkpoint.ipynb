# %%
from sudoku import times
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.DataFrame()
df['Index'] = times.keys()
df['Time'] = times.values()
df.set_index('Index', inplace=True)
df
# Out:
#          Time
# Index
# 1      10.969
# 2       7.976
# 3       6.562
# 4      14.959
# 5       8.976
# ...       ...
# 996     8.919
# 997    34.906
# 998     9.975
# 999    12.767
# 1000    6.061
#
# [1000 rows x 1 columns]

# %%
plt.figure(figsize=(80,40))
z = sns.lineplot(data = df[:199], color = 'r')
